# %% [markdown]
# COMP 215 - LAB 2 Records (NEO)
# ----------------
# #### Name:
# #### Date:
#
# This lab exercise is mostly a review of strings, tuples, lists, dictionaries, and functions.
#
# **Building on new concepts from lab 1**:
#   * `datetime.date` objects represent a calendar date
#   * *list comprehension* provides a compact way to represent map and filter algorithms
#
# **New Python Concepts**:
#   * *f-string* simplifies string formatting operations
#
# As usual, the first code cell simply imports all the modules we'll be using...

# %%
import json, requests
from datetime import date, datetime
from pprint import pprint    # Pretty Print - built-in python function to nicely format data structures

# %% [markdown]
# We'll answer some questions about [Near Earth Objects](https://cneos.jpl.nasa.gov/)
# > using NASA's API:  [https://api.nasa.gov/](https://api.nasa.gov/#NeoWS)
#
# You should register for your own API key, (but may use the DEMO_KEY to get started).
#
# First, a short reminder about python dates and [f-strings](https://realpython.com/python-f-strings/)...

# %%
today = date.today()   # get a date object representing today's date
print(today, type(today))
# f"..."  is a format string - notice how the variable `today` is formatted into the string
print(f'Today is: {today}')
# Out:
# 2026-01-14 <class 'datetime.date'>
# Today is: 2026-01-14

# %% [markdown]
# ### Make a query
#
# Let's get some data from the NEO database...
# Here's a query that gets the observation "feed" for today.
# (Note: I hard-coded the date below to lock down the data for the lab - ideally used `today()` so the notebook is always up-to-date.)

# %%
NASA_NEO_FEED_API_URL = "https://api.nasa.gov/neo/rest/v1/feed"
API_KEY = 'nn9OEmof0eBFYQYLOGfwS8fQzYyRmbrdRWYUzgxI'  # substitute your API key here

start_date = '2023-01-09'  #  Future enhancement:  str(date.today())   # Today's date as a string!

feed_params = dict(
    start_date=start_date,
    end_date=start_date,
    api_key=API_KEY,
)

response = requests.request("GET", NASA_NEO_FEED_API_URL, params=feed_params)
response.raise_for_status()  # raise an error if request is not successful

feed_data = json.loads(response.text)  # recall json.loads from lab 1

# TIP: print(data) to see the whole data structure returned, here we grab just the list of NEO's:
n_results = feed_data['element_count']
neos = feed_data['near_earth_objects'][start_date]
print(f'{n_results} Near Earth Objects found for {start_date}')
pprint(neos[:2])
# Out:
# 11 Near Earth Objects found for 2023-01-09
# [{'absolute_magnitude_h': 19.62,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 13:59',
#                            'epoch_date_close_approach': 1673272740000,
#                            'miss_distance': {'astronomical': '0.0725378623',
#                                              'kilometers': '10851509.694433301',
#                                              'lunar': '28.2172284347',
#                                              'miles': '6742815.4556135138'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '32387.3479203461',
#                                                  'kilometers_per_second': '8.9964855334',
#                                                  'miles_per_hour': '20124.2384897284'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 2322.8706681664,
#                                   'estimated_diameter_min': 1038.8193433921},
#                          'kilometers': {'estimated_diameter_max': 0.708010957,
#                                         'estimated_diameter_min': 0.3166321257},
#                          'meters': {'estimated_diameter_max': 708.0109570008,
#                                     'estimated_diameter_min': 316.6321257337},
#                          'miles': {'estimated_diameter_max': 0.4399374764,
#                                    'estimated_diameter_min': 0.1967460206}},
#   'id': '2226554',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2226554?api_key=nn9OEmof0eBFYQYLOGfwS8fQzYyRmbrdRWYUzgxI'},
#   'name': '226554 (2003 WR21)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2226554',
#   'neo_reference_id': '2226554'},
#  {'absolute_magnitude_h': 20.95,
#   'close_approach_data': [{'close_approach_date': '2023-01-09',
#                            'close_approach_date_full': '2023-Jan-09 03:25',
#                            'epoch_date_close_approach': 1673234700000,
#                            'miss_distance': {'astronomical': '0.1211166399',
#                                              'kilometers': '18118791.350597013',
#                                              'lunar': '47.1143729211',
#                                              'miles': '11258494.8819162594'},
#                            'orbiting_body': 'Earth',
#                            'relative_velocity': {'kilometers_per_hour': '22658.3665761987',
#                                                  'kilometers_per_second': '6.2939907156',
#                                                  'miles_per_hour': '14079.0278317497'}}],
#   'estimated_diameter': {'feet': {'estimated_diameter_max': 1258.997970434,
#                                   'estimated_diameter_min': 563.0410090849},
#                          'kilometers': {'estimated_diameter_max': 0.3837425691,
#                                         'estimated_diameter_min': 0.1716148941},
#                          'meters': {'estimated_diameter_max': 383.7425691085,
#                                     'estimated_diameter_min': 171.6148940774},
#                          'miles': {'estimated_diameter_max': 0.2384465039,
#                                    'estimated_diameter_min': 0.1066365183}},
#   'id': '2508908',
#   'is_potentially_hazardous_asteroid': True,
#   'is_sentry_object': False,
#   'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/2508908?api_key=nn9OEmof0eBFYQYLOGfwS8fQzYyRmbrdRWYUzgxI'},
#   'name': '508908 (2003 YX1)',
#   'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=2508908',
#   'neo_reference_id': '2508908'}]

# %% [markdown]
# Next we extract just the potentially hazerdous asteroids, using a Comp115-style list accumulator *loop*:

# %%
hazards =  []
for item in neos:
  if item['is_potentially_hazardous_asteroid'] is True:
    hazards.append(item)
print(f'{len(hazards)} potentially hazardous asteroids identified on {start_date}.')
# Out:
# 2 potentially hazardous asteroids identified on 2023-01-09.

# %% [markdown]
# ## Exercise 1
#
# In the code cell below, **re-write the accumulator loop above** as a [list comprehension](https://realpython.com/lessons/list-comprehensions-overview/) that implements a ["filter"](https://youtu.be/hUes6y2b--0)
# Notice how this provides a concise way to "filter" items of interest from a larger data set.

# %%
# Ex. 1 your code here

hazards = [neo for neo in neos if neo['is_potentially_hazardous_asteroid'] is True]
print(f'{len(hazards)} potentially hazardous asteroids identified on {start_date}.')
# Out:
# 2 potentially hazardous asteroids identified on 2023-01-09.

# %% [markdown]
# ## Fetch Complete Data for One Asteroid
#
# Notice that the record for each `neo` is a dictionary with `id` field that uniquely identifies this record in the database.
#
# We can use this `id` to fetch complete orbital and close approach data for the NEO.
#
# For example, this query fetches the complete data set for the first hazardous asteroid...

# %%
NASA_NEO_API_URL = "https://api.nasa.gov/neo/rest/v1/neo/{id}"
neo_params = dict(
    api_key=API_KEY,
)
hazard_id = hazards[0]['id']

response = requests.request("GET", NASA_NEO_API_URL.format(id=hazard_id), params=neo_params)
response.raise_for_status()  # raise an error if request is not successful

neo_data = json.loads(response.text)

print(f'NEO {neo_data["name"]} with {len(neo_data["close_approach_data"])} approach records.  {"Hazardous." if neo_data["is_potentially_hazardous_asteroid"] else ""}')
print(f'Close approach records:')
close_approach_data = neo_data['close_approach_data']
pprint(close_approach_data[:3])
# Out:
# NEO 226554 (2003 WR21) with 130 approach records.  Hazardous.
# Close approach records:
# [{'close_approach_date': '1900-10-30',
#   'close_approach_date_full': '1900-Oct-30 21:15',
#   'epoch_date_close_approach': -2182819500000,
#   'miss_distance': {'astronomical': '0.4183488933',
#                     'kilometers': '62584103.354537271',
#                     'lunar': '162.7377194937',
#                     'miles': '38887958.5659094998'},
#   'orbiting_body': 'Earth',
#   'relative_velocity': {'kilometers_per_hour': '30027.9671888418',
#                         'kilometers_per_second': '8.3411019969',
#                         'miles_per_hour': '18658.2110568667'}},
#  {'close_approach_date': '1901-06-26',
#   'close_approach_date_full': '1901-Jun-26 20:27',
#   'epoch_date_close_approach': -2162172780000,
#   'miss_distance': {'astronomical': '0.0308794402',
#                     'kilometers': '4619498.480712374',
#                     'lunar': '12.0121022378',
#                     'miles': '2870423.2526198012'},
#   'orbiting_body': 'Earth',
#   'relative_velocity': {'kilometers_per_hour': '33428.9789814113',
#                         'kilometers_per_second': '9.2858274948',
#                         'miles_per_hour': '20771.4675231997'}},
#  {'close_approach_date': '1907-01-08',
#   'close_approach_date_full': '1907-Jan-08 04:37',
#   'epoch_date_close_approach': -1987528980000,
#   'miss_distance': {'astronomical': '0.124028823',
#                     'kilometers': '18554447.73940701',
#                     'lunar': '48.247212147',
#                     'miles': '11529199.209196338'},
#   'orbiting_body': 'Earth',
#   'relative_velocity': {'kilometers_per_hour': '24041.8328517503',
#                         'kilometers_per_second': '6.6782869033',
#                         'miles_per_hour': '14938.6599739112'}}]

# %% [markdown]
# Notice that the `miss_distance` field contains the distance (in various units) by which the NEO missed an "orbiting body".
#
# ## Exercise 2
#
# In the code cell below, write a python function that takes a list of "close approach data" as a parameter,
# and returns a 2-tuple with the (date, miss km) of the closest approach to Earth in the list (where "miss km" is the miss distance in km).
#
# Hints:
# * notice the input is a list of dictionaries.  Each dictionary has a 'close_approach_date", "orbiting_body", and 'miss_distance' field.
# * we are only interested in the closest approach to "Earth"
# * use a loop if that is easier to understand - we will look at more compact algorithms to solve this problem in class.
#
# Add at least one unit test to check your work - note the test data only needs dictionaries with the fields your function actually uses.

# %%
# Ex. 2 your code here

def closest_miss(data):
  date = ""
  miss_km = float('inf')

  # Using list comprehension

  # outputs = [["-1", float('inf')]]
  # idk = [outputs.append([record["close_approach_date"], record["miss_distance"]["kilometers"]]) for record in data if (float(record["miss_distance"]["kilometers"]) < float(outputs[-1][1])) and record["orbiting_body"] == "Earth"]
  # return tuple(outputs[-1])


  # Using for loop

  for record in data:
    if record["orbiting_body"] == "Earth" and (float(record["miss_distance"]["kilometers"]) < float(miss_km)):
      miss_km = record["miss_distance"]["kilometers"]
      date = record["close_approach_date"]
  return (date, miss_km)


print(closest_miss(close_approach_data))

# Test case
assert ('1900-10-30', "2") == closest_miss([{'close_approach_date': '1900-10-30',
  'close_approach_date_full': '1900-Oct-30 21:15',
  'epoch_date_close_approach': -2182819500000,
  'miss_distance': {'astronomical': '0.4183488933',
                    'kilometers': '2',
                    'lunar': '162.7377194937',
                    'miles': '38887958.5659094998'},
  'orbiting_body': 'Earth',
  'relative_velocity': {'kilometers_per_hour': '30027.9671888418',
                        'kilometers_per_second': '8.3411019969',
                        'miles_per_hour': '18658.2110568667'}},
 {'close_approach_date': '1901-06-26',
  'close_approach_date_full': '1901-Jun-26 20:27',
  'epoch_date_close_approach': -2162172780000,
  'miss_distance': {'astronomical': '0.0308794402',
                    'kilometers': '4619498.480712374',
                    'lunar': '12.0121022378',
                    'miles': '2870423.2526198012'},
  'orbiting_body': 'Venus',
  'relative_velocity': {'kilometers_per_hour': '33428.9789814113',
                        'kilometers_per_second': '9.2858274948',
                        'miles_per_hour': '20771.4675231997'}},
 {'close_approach_date': '1907-01-08',
  'close_approach_date_full': '1907-Jan-08 04:37',
  'epoch_date_close_approach': -1987528980000,
  'miss_distance': {'astronomical': '0.124028823',
                    'kilometers': '18554447.73940701',
                    'lunar': '48.247212147',
                    'miles': '11529199.209196338'},
  'orbiting_body': 'idk',
  'relative_velocity': {'kilometers_per_hour': '24041.8328517503',
                        'kilometers_per_second': '6.6782869033',
                        'miles_per_hour': '14938.6599739112'}}])
# Out:
# ('1972-06-25', '4303829.232704992')

# %% [markdown]
# ## Challenge - Take your skills to the next level...
# ## Exercise 3
#
# In the code cell below, write a complete program that:
#  1. fetches the list of NEO's for this week.
#  2. for each NEO, fetch it's complete orbital data and determine its closest approach to Earth
#  3. identify which NEO from this week's data makes the closet approach to earth
#  4. print a nice message with information about the NEO, when it will approach the Earth, and how close it will come.
#
# Hints:
# * you'll need the start and end date - end date is today, see if you can use a [`timedelta`](https://docs.python.org/3/library/datetime.html#timedelta-objects) object to ge the start date (you can do basic "date math" with `timedelta` and `date` objects!)
# * you may need to modify the function we wrote in Ex. 2 to return a triple with the NEO's id included;
# * lots of opportunity here for more practice with list comprehensions

# %%
# Ex. 3 (challenge) your code here

from datetime import timedelta

NASA_NEO_FEED_API_URL = "https://api.nasa.gov/neo/rest/v1/feed"
API_KEY = 'nn9OEmof0eBFYQYLOGfwS8fQzYyRmbrdRWYUzgxI'  # substitute your API key here


start_date = str(date.today())
end_date = str(date.today() + timedelta(days=7))


feed_params = dict(
    start_date=start_date,
    end_date=end_date,
    api_key=API_KEY,
)

response = requests.request("GET", NASA_NEO_FEED_API_URL, params=feed_params)
response.raise_for_status()  # raise an error if request is not successful

feed_data = json.loads(response.text)  # recall json.loads from lab 1

weekly_data = feed_data['near_earth_objects']

NASA_NEO_API_URL = "https://api.nasa.gov/neo/rest/v1/neo/{id}"
neo_params = dict(
    api_key=API_KEY,
)

neos_data = [json.loads(requests.request("GET", NASA_NEO_API_URL.format(id=neo["id"]), params=neo_params).text) for day in weekly_data for neo in weekly_data[day]]

# %%
# pprint(neos_data[-1])
# Out:
# {'absolute_magnitude_h': 24.932,
#  'close_approach_data': [{'close_approach_date': '1906-09-22',
#                           'close_approach_date_full': '1906-Sep-22 19:05',
#                           'epoch_date_close_approach': -1996808100000,
#                           'miss_distance': {'astronomical': '0.1020783308',
#                                             'kilometers': '15270700.860835396',
#                                             'lunar': '39.7084706812',
#                                             'miles': '9488773.5146486248'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '16397.1313806985',
#                                                 'kilometers_per_second': '4.5547587169',
#                                                 'miles_per_hour': '10188.5397737457'}},
#                          {'close_approach_date': '1908-01-26',
#                           'close_approach_date_full': '1908-Jan-26 02:41',
#                           'epoch_date_close_approach': -1954444740000,
#                           'miss_distance': {'astronomical': '0.1558630857',
#                                             'kilometers': '23316785.632347459',
#                                             'lunar': '60.6307403373',
#                                             'miles': '14488378.7568905742'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '33060.2576787831',
#                                                 'kilometers_per_second': '9.1834049108',
#                                                 'miles_per_hour': '20542.3584449083'}},
#                          {'close_approach_date': '1929-09-24',
#                           'close_approach_date_full': '1929-Sep-24 15:37',
#                           'epoch_date_close_approach': -1270801380000,
#                           'miss_distance': {'astronomical': '0.1095632609',
#                                             'kilometers': '16390430.460894283',
#                                             'lunar': '42.6201084901',
#                                             'miles': '10184541.2249477854'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '20355.9497273746',
#                                                 'kilometers_per_second': '5.6544304798',
#                                                 'miles_per_hour': '12648.3955403234'}},
#                          {'close_approach_date': '1931-01-26',
#                           'close_approach_date_full': '1931-Jan-26 07:04',
#                           'epoch_date_close_approach': -1228582560000,
#                           'miss_distance': {'astronomical': '0.1132345275',
#                                             'kilometers': '16939644.124456425',
#                                             'lunar': '44.0482311975',
#                                             'miles': '10525806.770791665'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28234.1443809294',
#                                                 'kilometers_per_second': '7.8428178836',
#                                                 'miles_per_hour': '17543.5993238058'}},
#                          {'close_approach_date': '1952-09-29',
#                           'close_approach_date_full': '1952-Sep-29 15:34',
#                           'epoch_date_close_approach': -544523160000,
#                           'miss_distance': {'astronomical': '0.1831113928',
#                                             'kilometers': '27393074.335613336',
#                                             'lunar': '71.2303317992',
#                                             'miles': '17021267.1055065968'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '32484.1425033266',
#                                                 'kilometers_per_second': '9.0233729176',
#                                                 'miles_per_hour': '20184.3828793587'}},
#                          {'close_approach_date': '1953-06-20',
#                           'close_approach_date_full': '1953-Jun-20 10:58',
#                           'epoch_date_close_approach': -521730120000,
#                           'miss_distance': {'astronomical': '0.1949946103',
#                                             'kilometers': '29170778.362360061',
#                                             'lunar': '75.8529034067',
#                                             'miles': '18125881.1660924018'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '23047.0150294228',
#                                                 'kilometers_per_second': '6.4019486193',
#                                                 'miles_per_hour': '14320.5188664766'}},
#                          {'close_approach_date': '1954-01-20',
#                           'close_approach_date_full': '1954-Jan-20 17:05',
#                           'epoch_date_close_approach': -503218500000,
#                           'miss_distance': {'astronomical': '0.0394008075',
#                                             'kilometers': '5894276.878280025',
#                                             'lunar': '15.3269141175',
#                                             'miles': '3662533.818213345'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '17815.5684155486',
#                                                 'kilometers_per_second': '4.9487690043',
#                                                 'miles_per_hour': '11069.9013857613'}},
#                          {'close_approach_date': '1964-09-21',
#                           'close_approach_date_full': '1964-Sep-21 16:19',
#                           'epoch_date_close_approach': -166520460000,
#                           'miss_distance': {'astronomical': '0.1014279553',
#                                             'kilometers': '15173406.071335211',
#                                             'lunar': '39.4554746117',
#                                             'miles': '9428317.3358434718'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '16784.9525364733',
#                                                 'kilometers_per_second': '4.6624868157',
#                                                 'miles_per_hour': '10429.5167580103'}},
#                          {'close_approach_date': '1966-01-26',
#                           'close_approach_date_full': '1966-Jan-26 00:50',
#                           'epoch_date_close_approach': -124067400000,
#                           'miss_distance': {'astronomical': '0.1348957086',
#                                             'kilometers': '20180110.678700682',
#                                             'lunar': '52.4744306454',
#                                             'miles': '12539339.3188541316'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30768.8851323216',
#                                                 'kilometers_per_second': '8.5469125368',
#                                                 'miles_per_hour': '19118.5886534695'}},
#                          {'close_approach_date': '1976-08-22',
#                           'close_approach_date_full': '1976-Aug-22 19:25',
#                           'epoch_date_close_approach': 209589900000,
#                           'miss_distance': {'astronomical': '0.1275626612',
#                                             'kilometers': '19083102.407051644',
#                                             'lunar': '49.6218752068',
#                                             'miles': '11857689.9873509272'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '14757.8628778678',
#                                                 'kilometers_per_second': '4.099406355',
#                                                 'miles_per_hour': '9169.9620754173'}},
#                          {'close_approach_date': '1976-11-05',
#                           'close_approach_date_full': '1976-Nov-05 23:56',
#                           'epoch_date_close_approach': 216086160000,
#                           'miss_distance': {'astronomical': '0.1196048892',
#                                             'kilometers': '17892636.665906004',
#                                             'lunar': '46.5263018988',
#                                             'miles': '11117968.8771266952'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '14299.9482956437',
#                                                 'kilometers_per_second': '3.9722078599',
#                                                 'miles_per_hour': '8885.4317618126'}},
#                          {'close_approach_date': '1988-08-12',
#                           'close_approach_date_full': '1988-Aug-12 08:45',
#                           'epoch_date_close_approach': 587378700000,
#                           'miss_distance': {'astronomical': '0.1391667524',
#                                             'kilometers': '20819049.733857388',
#                                             'lunar': '54.1358666836',
#                                             'miles': '12936357.6377444344'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '16370.2706722978',
#                                                 'kilometers_per_second': '4.547297409',
#                                                 'miles_per_hour': '10171.8495741286'}},
#                          {'close_approach_date': '1988-11-16',
#                           'close_approach_date_full': '1988-Nov-16 20:18',
#                           'epoch_date_close_approach': 595714680000,
#                           'miss_distance': {'astronomical': '0.1205287134',
#                                             'kilometers': '18030838.798480458',
#                                             'lunar': '46.8856695126',
#                                             'miles': '11203843.7002400004'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '15316.7468658982',
#                                                 'kilometers_per_second': '4.2546519072',
#                                                 'miles_per_hour': '9517.2308512021'}},
#                          {'close_approach_date': '1989-04-24',
#                           'close_approach_date_full': '1989-Apr-24 15:26',
#                           'epoch_date_close_approach': 609434760000,
#                           'miss_distance': {'astronomical': '0.1991518525',
#                                             'kilometers': '29792692.940554175',
#                                             'lunar': '77.4700706225',
#                                             'miles': '18512320.965530615'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '19463.1074910048',
#                                                 'kilometers_per_second': '5.4064187475',
#                                                 'miles_per_hour': '12093.6180962857'}},
#                          {'close_approach_date': '2000-08-26',
#                           'close_approach_date_full': '2000-Aug-26 10:45',
#                           'epoch_date_close_approach': 967286700000,
#                           'miss_distance': {'astronomical': '0.1237113874',
#                                             'kilometers': '18506960.049784838',
#                                             'lunar': '48.1237296986',
#                                             'miles': '11499691.7271452444'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '14318.3002749096',
#                                                 'kilometers_per_second': '3.9773056319',
#                                                 'miles_per_hour': '8896.8349680403'}},
#                          {'close_approach_date': '2000-10-30',
#                           'close_approach_date_full': '2000-Oct-30 09:21',
#                           'epoch_date_close_approach': 972897660000,
#                           'miss_distance': {'astronomical': '0.1200862557',
#                                             'kilometers': '17964648.068995359',
#                                             'lunar': '46.7135534673',
#                                             'miles': '11162714.6881155942'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '13886.3794795604',
#                                                 'kilometers_per_second': '3.8573276332',
#                                                 'miles_per_hour': '8628.4561827302'}},
#                          {'close_approach_date': '2002-01-25',
#                           'close_approach_date_full': '2002-Jan-25 10:45',
#                           'epoch_date_close_approach': 1011955500000,
#                           'miss_distance': {'astronomical': '0.1883231822',
#                                             'kilometers': '28172746.928741914',
#                                             'lunar': '73.2577178758',
#                                             'miles': '17505733.1898858532'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '36929.0199344778',
#                                                 'kilometers_per_second': '10.2580610929',
#                                                 'miles_per_hour': '22946.2568587315'}},
#                          {'close_approach_date': '2012-09-21',
#                           'close_approach_date_full': '2012-Sep-21 00:49',
#                           'epoch_date_close_approach': 1348188540000,
#                           'miss_distance': {'astronomical': '0.1014466534',
#                                             'kilometers': '15176203.267268258',
#                                             'lunar': '39.4627481726',
#                                             'miles': '9430055.4327996404'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '17392.1209346938',
#                                                 'kilometers_per_second': '4.8311447041',
#                                                 'miles_per_hour': '10806.7875885602'}},
#                          {'close_approach_date': '2014-01-26',
#                           'close_approach_date_full': '2014-Jan-26 23:03',
#                           'epoch_date_close_approach': 1390777380000,
#                           'miss_distance': {'astronomical': '0.1006293099',
#                                             'kilometers': '15053930.420609913',
#                                             'lunar': '39.1448015511',
#                                             'miles': '9354078.6089782794'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '27157.7378672569',
#                                                 'kilometers_per_second': '7.5438160742',
#                                                 'miles_per_hour': '16874.7621764631'}},
#                          {'close_approach_date': '2024-09-26',
#                           'close_approach_date_full': '2024-Sep-26 21:03',
#                           'epoch_date_close_approach': 1727384580000,
#                           'miss_distance': {'astronomical': '0.1505975188',
#                                             'kilometers': '22529068.039764956',
#                                             'lunar': '58.5824348132',
#                                             'miles': '13998913.7416541528'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '28516.7531450172',
#                                                 'kilometers_per_second': '7.9213203181',
#                                                 'miles_per_hour': '17719.2014194692'}},
#                          {'close_approach_date': '2025-06-16',
#                           'close_approach_date_full': '2025-Jun-16 13:19',
#                           'epoch_date_close_approach': 1750079940000,
#                           'miss_distance': {'astronomical': '0.1988790847',
#                                             'kilometers': '29751887.458669589',
#                                             'lunar': '77.3639639483',
#                                             'miles': '18486965.6148307682'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '23520.8656652462',
#                                                 'kilometers_per_second': '6.5335737959',
#                                                 'miles_per_hour': '14614.9512240526'}},
#                          {'close_approach_date': '2026-01-21',
#                           'close_approach_date_full': '2026-Jan-21 00:45',
#                           'epoch_date_close_approach': 1768956300000,
#                           'miss_distance': {'astronomical': '0.0438853019',
#                                             'kilometers': '6565147.688546953',
#                                             'lunar': '17.0713824391',
#                                             'miles': '4079393.6096678314'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '17741.7278184738',
#                                                 'kilometers_per_second': '4.9282577274',
#                                                 'miles_per_hour': '11024.0197103178'}},
#                          {'close_approach_date': '2037-07-19',
#                           'close_approach_date_full': '2037-Jul-19 01:28',
#                           'epoch_date_close_approach': 2131579680000,
#                           'miss_distance': {'astronomical': '0.1688325837',
#                                             'kilometers': '25256994.908116719',
#                                             'lunar': '65.6758750593',
#                                             'miles': '15693968.8968959622'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '20313.3138508052',
#                                                 'kilometers_per_second': '5.6425871808',
#                                                 'miles_per_hour': '12621.9032646851'}},
#                          {'close_approach_date': '2037-12-12',
#                           'close_approach_date_full': '2037-Dec-12 22:59',
#                           'epoch_date_close_approach': 2144271540000,
#                           'miss_distance': {'astronomical': '0.1081804604',
#                                             'kilometers': '16183566.451459348',
#                                             'lunar': '42.0821990956',
#                                             'miles': '10056001.8899330824'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '16394.4921270476',
#                                                 'kilometers_per_second': '4.5540255908',
#                                                 'miles_per_hour': '10186.8998441646'}},
#                          {'close_approach_date': '2038-04-01',
#                           'close_approach_date_full': '2038-Apr-01 06:37',
#                           'epoch_date_close_approach': 2153716620000,
#                           'miss_distance': {'astronomical': '0.1793893243',
#                                             'kilometers': '26836260.816019241',
#                                             'lunar': '69.7824471527',
#                                             'miles': '16675279.2281018858'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '14356.6625031763',
#                                                 'kilometers_per_second': '3.9879618064',
#                                                 'miles_per_hour': '8920.6717648209'}},
#                          {'close_approach_date': '2049-09-15',
#                           'close_approach_date_full': '2049-Sep-15 11:48',
#                           'epoch_date_close_approach': 2515319280000,
#                           'miss_distance': {'astronomical': '0.1059472003',
#                                             'kilometers': '15849475.497343361',
#                                             'lunar': '41.2134609167',
#                                             'miles': '9848407.3973299418'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '13790.1879373558',
#                                                 'kilometers_per_second': '3.8306077604',
#                                                 'miles_per_hour': '8568.6864991864'}},
#                          {'close_approach_date': '2051-01-26',
#                           'close_approach_date_full': '2051-Jan-26 23:39',
#                           'epoch_date_close_approach': 2558389140000,
#                           'miss_distance': {'astronomical': '0.128704351',
#                                             'kilometers': '19253896.76933237',
#                                             'lunar': '50.065992539',
#                                             'miles': '11963816.682911906'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30362.4833108959',
#                                                 'kilometers_per_second': '8.4340231419',
#                                                 'miles_per_hour': '18866.0663661508'}},
#                          {'close_approach_date': '2061-09-27',
#                           'close_approach_date_full': '2061-Sep-27 08:18',
#                           'epoch_date_close_approach': 2895034680000,
#                           'miss_distance': {'astronomical': '0.1591333678',
#                                             'kilometers': '23806012.868806586',
#                                             'lunar': '61.9028800742',
#                                             'miles': '14792370.4653434468'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '29865.4160802822',
#                                                 'kilometers_per_second': '8.2959489112',
#                                                 'miles_per_hour': '18557.2081194398'}},
#                          {'close_approach_date': '2062-06-19',
#                           'close_approach_date_full': '2062-Jun-19 13:22',
#                           'epoch_date_close_approach': 2917948920000,
#                           'miss_distance': {'astronomical': '0.1969980696',
#                                             'kilometers': '29470491.606271752',
#                                             'lunar': '76.6322490744',
#                                             'miles': '18312114.3401120976'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '23416.7970148075',
#                                                 'kilometers_per_second': '6.5046658374',
#                                                 'miles_per_hour': '14550.2870117842'}},
#                          {'close_approach_date': '2063-01-18',
#                           'close_approach_date_full': '2063-Jan-18 06:40',
#                           'epoch_date_close_approach': 2936328000000,
#                           'miss_distance': {'astronomical': '0.0496345802',
#                                             'kilometers': '7425227.476264174',
#                                             'lunar': '19.3078516978',
#                                             'miles': '4613822.4079626412'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '16881.8765382407',
#                                                 'kilometers_per_second': '4.6894101495',
#                                                 'miles_per_hour': '10489.7415634418'}},
#                          {'close_approach_date': '2086-09-22',
#                           'close_approach_date_full': '2086-Sep-22 22:19',
#                           'epoch_date_close_approach': 3683571540000,
#                           'miss_distance': {'astronomical': '0.1064888787',
#                                             'kilometers': '15930509.432208369',
#                                             'lunar': '41.4241738143',
#                                             'miles': '9898759.5495947322'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '20427.3081820346',
#                                                 'kilometers_per_second': '5.6742522728',
#                                                 'miles_per_hour': '12692.7349089981'}},
#                          {'close_approach_date': '2088-01-26',
#                           'close_approach_date_full': '2088-Jan-26 15:08',
#                           'epoch_date_close_approach': 3725968080000,
#                           'miss_distance': {'astronomical': '0.0691658069',
#                                             'kilometers': '10347057.389071303',
#                                             'lunar': '26.9054988841',
#                                             'miles': '6429363.3280298614'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '23347.4115975671',
#                                                 'kilometers_per_second': '6.4853921104',
#                                                 'miles_per_hour': '14507.1736118327'}},
#                          {'close_approach_date': '2098-09-28',
#                           'close_approach_date_full': '2098-Sep-28 10:35',
#                           'epoch_date_close_approach': 4062738900000,
#                           'miss_distance': {'astronomical': '0.1704724693',
#                                             'kilometers': '25502318.300920391',
#                                             'lunar': '66.3137905577',
#                                             'miles': '15846405.7845917558'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '31356.9434477871',
#                                                 'kilometers_per_second': '8.7102620688',
#                                                 'miles_per_hour': '19483.9852217652'}},
#                          {'close_approach_date': '2099-06-21',
#                           'close_approach_date_full': '2099-Jun-21 09:07',
#                           'epoch_date_close_approach': 4085716020000,
#                           'miss_distance': {'astronomical': '0.1959072117',
#                                             'kilometers': '29307301.587959079',
#                                             'lunar': '76.2079053513',
#                                             'miles': '18210712.7647861302'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '23223.0575725605',
#                                                 'kilometers_per_second': '6.4508493257',
#                                                 'miles_per_hour': '14429.9048566835'}},
#                          {'close_approach_date': '2100-01-17',
#                           'close_approach_date_full': '2100-Jan-17 11:54',
#                           'epoch_date_close_approach': 4103870040000,
#                           'miss_distance': {'astronomical': '0.05008996',
#                                             'kilometers': '7493351.3243852',
#                                             'lunar': '19.48499444',
#                                             'miles': '4656152.60430776'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '16704.1732523819',
#                                                 'kilometers_per_second': '4.6400481257',
#                                                 'miles_per_hour': '10379.3236522925'}},
#                          {'close_approach_date': '2111-07-08',
#                           'close_approach_date_full': '2111-Jul-08 01:10',
#                           'epoch_date_close_approach': 4465761000000,
#                           'miss_distance': {'astronomical': '0.1818370467',
#                                             'kilometers': '27202434.873410529',
#                                             'lunar': '70.7346111663',
#                                             'miles': '16902809.2366581402'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '21752.0134859814',
#                                                 'kilometers_per_second': '6.0422259683',
#                                                 'miles_per_hour': '13515.8552685533'}},
#                          {'close_approach_date': '2111-12-30',
#                           'close_approach_date_full': '2111-Dec-30 23:44',
#                           'epoch_date_close_approach': 4480962240000,
#                           'miss_distance': {'astronomical': '0.0836431532',
#                                             'kilometers': '12512837.558803684',
#                                             'lunar': '32.5371865948',
#                                             'miles': '7775116.7220874792'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '15987.7490394293',
#                                                 'kilometers_per_second': '4.4410413998',
#                                                 'miles_per_hour': '9934.1655073054'}},
#                          {'close_approach_date': '2117-01-31',
#                           'close_approach_date_full': '2117-Jan-31 07:58',
#                           'epoch_date_close_approach': 4641523080000,
#                           'miss_distance': {'astronomical': '0.1489010579',
#                                             'kilometers': '22275281.102586673',
#                                             'lunar': '57.9225115231',
#                                             'miles': '13841217.8513471674'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8413.2690618858',
#                                                 'kilometers_per_second': '2.3370191839',
#                                                 'miles_per_hour': '5227.6782123701'}},
#                          {'close_approach_date': '2118-12-05',
#                           'close_approach_date_full': '2118-Dec-05 10:48',
#                           'epoch_date_close_approach': 4699680480000,
#                           'miss_distance': {'astronomical': '0.1459333936',
#                                             'kilometers': '21831324.844431632',
#                                             'lunar': '56.7680901104',
#                                             'miles': '13565356.2244032416'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8163.0577319758',
#                                                 'kilometers_per_second': '2.2675160367',
#                                                 'miles_per_hour': '5072.2066224046'}},
#                          {'close_approach_date': '2120-10-09',
#                           'close_approach_date_full': '2120-Oct-09 03:39',
#                           'epoch_date_close_approach': 4757888340000,
#                           'miss_distance': {'astronomical': '0.1445878886',
#                                             'kilometers': '21630040.162357282',
#                                             'lunar': '56.2446886654',
#                                             'miles': '13440283.7226512116'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8060.3139939305',
#                                                 'kilometers_per_second': '2.2389761094',
#                                                 'miles_per_hour': '5008.3656591731'}},
#                          {'close_approach_date': '2122-08-14',
#                           'close_approach_date_full': '2122-Aug-14 13:33',
#                           'epoch_date_close_approach': 4816157580000,
#                           'miss_distance': {'astronomical': '0.1453764175',
#                                             'kilometers': '21748002.406230725',
#                                             'lunar': '56.5514264075',
#                                             'miles': '13513582.062105005'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8134.8030189303',
#                                                 'kilometers_per_second': '2.2596675053',
#                                                 'miles_per_hour': '5054.6502425126'}},
#                          {'close_approach_date': '2123-07-09',
#                           'close_approach_date_full': '2123-Jul-09 23:21',
#                           'epoch_date_close_approach': 4844618460000,
#                           'miss_distance': {'astronomical': '0.1792720206',
#                                             'kilometers': '26818712.432356122',
#                                             'lunar': '69.7368160134',
#                                             'miles': '16664375.1681216036'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '21509.1608454352',
#                                                 'kilometers_per_second': '5.9747669015',
#                                                 'miles_per_hour': '13364.9560819872'}},
#                          {'close_approach_date': '2124-06-19',
#                           'close_approach_date_full': '2124-Jun-19 01:55',
#                           'epoch_date_close_approach': 4874435700000,
#                           'miss_distance': {'astronomical': '0.1473531029',
#                                             'kilometers': '22043710.331730823',
#                                             'lunar': '57.3203570281',
#                                             'miles': '13697326.4466704374'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8295.9555785709',
#                                                 'kilometers_per_second': '2.3044321052',
#                                                 'miles_per_hour': '5154.7841760292'}},
#                          {'close_approach_date': '2126-04-24',
#                           'close_approach_date_full': '2126-Apr-24 10:01',
#                           'epoch_date_close_approach': 4932698460000,
#                           'miss_distance': {'astronomical': '0.1478329908',
#                                             'kilometers': '22115500.539409596',
#                                             'lunar': '57.5070334212',
#                                             'miles': '13741934.8132045848'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8349.7512394485',
#                                                 'kilometers_per_second': '2.3193753443',
#                                                 'miles_per_hour': '5188.2107076451'}},
#                          {'close_approach_date': '2128-02-28',
#                           'close_approach_date_full': '2128-Feb-28 06:13',
#                           'epoch_date_close_approach': 4991004780000,
#                           'miss_distance': {'astronomical': '0.1499060347',
#                                             'kilometers': '22425623.491266089',
#                                             'lunar': '58.3134474983',
#                                             'miles': '13934636.2798024682'},
#                           'orbiting_body': 'Venus',
#                           'relative_velocity': {'kilometers_per_hour': '8542.2662901713',
#                                                 'kilometers_per_second': '2.3728517473',
#                                                 'miles_per_hour': '5307.8320734678'}},
#                          {'close_approach_date': '2134-10-01',
#                           'close_approach_date_full': '2134-Oct-01 05:51',
#                           'epoch_date_close_approach': 5198968260000,
#                           'miss_distance': {'astronomical': '0.193914103',
#                                             'kilometers': '29009136.77176061',
#                                             'lunar': '75.432586067',
#                                             'miles': '18025441.739132018'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '33982.9168231448',
#                                                 'kilometers_per_second': '9.4396991175',
#                                                 'miles_per_hour': '21115.6629560257'}},
#                          {'close_approach_date': '2135-06-24',
#                           'close_approach_date_full': '2135-Jun-24 22:41',
#                           'epoch_date_close_approach': 5222011260000,
#                           'miss_distance': {'astronomical': '0.1922538586',
#                                             'kilometers': '28760767.745841182',
#                                             'lunar': '74.7867509954',
#                                             'miles': '17871112.3827730316'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '22858.3840826927',
#                                                 'kilometers_per_second': '6.3495511341',
#                                                 'miles_per_hour': '14203.3109318265'}},
#                          {'close_approach_date': '2136-01-17',
#                           'close_approach_date_full': '2136-Jan-17 23:29',
#                           'epoch_date_close_approach': 5239898940000,
#                           'miss_distance': {'astronomical': '0.0466293969',
#                                             'kilometers': '6975658.455624603',
#                                             'lunar': '18.1388353941',
#                                             'miles': '4334473.1721334014'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '16591.9832300094',
#                                                 'kilometers_per_second': '4.6088842306',
#                                                 'miles_per_hour': '10309.6131353356'}},
#                          {'close_approach_date': '2146-09-26',
#                           'close_approach_date_full': '2146-Sep-26 06:00',
#                           'epoch_date_close_approach': 5577228000000,
#                           'miss_distance': {'astronomical': '0.1124539725',
#                                             'kilometers': '16822874.759038575',
#                                             'lunar': '43.7445953025',
#                                             'miles': '10453249.651639335'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '21448.6095886001',
#                                                 'kilometers_per_second': '5.9579471079',
#                                                 'miles_per_hour': '13327.331885761'}},
#                          {'close_approach_date': '2148-01-26',
#                           'close_approach_date_full': '2148-Jan-26 20:41',
#                           'epoch_date_close_approach': 5619357660000,
#                           'miss_distance': {'astronomical': '0.0969679997',
#                                             'kilometers': '14506206.213280639',
#                                             'lunar': '37.7205518833',
#                                             'miles': '9013738.5683212582'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '26233.870754186',
#                                                 'kilometers_per_second': '7.2871863206',
#                                                 'miles_per_hour': '16300.7070805663'}},
#                          {'close_approach_date': '2158-08-08',
#                           'close_approach_date_full': '2158-Aug-08 01:06',
#                           'epoch_date_close_approach': 5951667960000,
#                           'miss_distance': {'astronomical': '0.1457068735',
#                                             'kilometers': '21797437.919959445',
#                                             'lunar': '56.6799737915',
#                                             'miles': '13544299.865932541'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '16958.0677270659',
#                                                 'kilometers_per_second': '4.7105743686',
#                                                 'miles_per_hour': '10537.0838051872'}},
#                          {'close_approach_date': '2158-11-26',
#                           'close_approach_date_full': '2158-Nov-26 13:20',
#                           'epoch_date_close_approach': 5961216000000,
#                           'miss_distance': {'astronomical': '0.1124266988',
#                                             'kilometers': '16818794.671611556',
#                                             'lunar': '43.7339858332',
#                                             'miles': '10450714.4028732328'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '15548.8846861284',
#                                                 'kilometers_per_second': '4.319134635',
#                                                 'miles_per_hour': '9661.4722651113'}},
#                          {'close_approach_date': '2159-04-15',
#                           'close_approach_date_full': '2159-Apr-15 16:56',
#                           'epoch_date_close_approach': 5973324960000,
#                           'miss_distance': {'astronomical': '0.1904057221',
#                                             'kilometers': '28484290.461971927',
#                                             'lunar': '74.0678258969',
#                                             'miles': '17699317.3648175126'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '17342.4979056471',
#                                                 'kilometers_per_second': '4.8173605293',
#                                                 'miles_per_hour': '10775.953768095'}},
#                          {'close_approach_date': '2169-09-30',
#                           'close_approach_date_full': '2169-Sep-30 00:43',
#                           'epoch_date_close_approach': 6303400980000,
#                           'miss_distance': {'astronomical': '0.1677946643',
#                                             'kilometers': '25101724.376645041',
#                                             'lunar': '65.2721244127',
#                                             'miles': '15597488.2625059258'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30416.8732305196',
#                                                 'kilometers_per_second': '8.4491314529',
#                                                 'miles_per_hour': '18899.8621470415'}},
#                          {'close_approach_date': '2170-06-16',
#                           'close_approach_date_full': '2170-Jun-16 00:54',
#                           'epoch_date_close_approach': 6325779240000,
#                           'miss_distance': {'astronomical': '0.1976776161',
#                                             'kilometers': '29572150.315237707',
#                                             'lunar': '76.8965926629',
#                                             'miles': '18375282.1327340766'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '23121.5791209593',
#                                                 'kilometers_per_second': '6.4226608669',
#                                                 'miles_per_hour': '14366.8500932427'}},
#                          {'close_approach_date': '2171-01-23',
#                           'close_approach_date_full': '2171-Jan-23 15:22',
#                           'epoch_date_close_approach': 6344925720000,
#                           'miss_distance': {'astronomical': '0.0452232916',
#                                             'kilometers': '6765308.097748892',
#                                             'lunar': '17.5918604324',
#                                             'miles': '4203767.5206510296'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '19543.0256454696',
#                                                 'kilometers_per_second': '5.4286182349',
#                                                 'miles_per_hour': '12143.2761295419'}},
#                          {'close_approach_date': '2192-09-25',
#                           'close_approach_date_full': '2192-Sep-25 12:36',
#                           'epoch_date_close_approach': 7028858160000,
#                           'miss_distance': {'astronomical': '0.1030554045',
#                                             'kilometers': '15416869.005188415',
#                                             'lunar': '40.0885523505',
#                                             'miles': '9579598.187953527'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '18485.7003833389',
#                                                 'kilometers_per_second': '5.1349167731',
#                                                 'miles_per_hour': '11486.2953298586'}},
#                          {'close_approach_date': '2194-01-25',
#                           'close_approach_date_full': '2194-Jan-25 17:02',
#                           'epoch_date_close_approach': 7070950920000,
#                           'miss_distance': {'astronomical': '0.1379558541',
#                                             'kilometers': '20637901.927390767',
#                                             'lunar': '53.6648272449',
#                                             'miles': '12823797.6102839046'},
#                           'orbiting_body': 'Earth',
#                           'relative_velocity': {'kilometers_per_hour': '30821.4673748863',
#                                                 'kilometers_per_second': '8.5615187152',
#                                                 'miles_per_hour': '19151.2612141342'}}],
#  'designation': '2026 AL',
#  'estimated_diameter': {'feet': {'estimated_diameter_max': 201.1986350057,
#                                  'estimated_diameter_min': 89.9787649706},
#                         'kilometers': {'estimated_diameter_max': 0.061325342,
#                                        'estimated_diameter_min': 0.0274255267},
#                         'meters': {'estimated_diameter_max': 61.3253419873,
#                                    'estimated_diameter_min': 27.4255266854},
#                         'miles': {'estimated_diameter_max': 0.0381057891,
#                                   'estimated_diameter_min': 0.0170414269}},
#  'id': '54574880',
#  'is_potentially_hazardous_asteroid': False,
#  'is_sentry_object': False,
#  'links': {'self': 'http://api.nasa.gov/neo/rest/v1/neo/54574880?api_key=nn9OEmof0eBFYQYLOGfwS8fQzYyRmbrdRWYUzgxI'},
#  'name': '(2026 AL)',
#  'nasa_jpl_url': 'https://ssd.jpl.nasa.gov/tools/sbdb_lookup.html#/?sstr=54574880',
#  'neo_reference_id': '54574880',
#  'orbital_data': {'aphelion_distance': '1.085064703526822',
#                   'ascending_node_longitude': '102.2908462129809',
#                   'data_arc_in_days': 4,
#                   'eccentricity': '.1430759396994772',
#                   'epoch_osculation': '2461000.5',
#                   'equinox': 'J2000',
#                   'first_observation_date': '2026-01-08',
#                   'inclination': '5.910845939430347',
#                   'jupiter_tisserand_invariant': '6.323',
#                   'last_observation_date': '2026-01-12',
#                   'mean_anomaly': '184.0260704674774',
#                   'mean_motion': '1.065695776391137',
#                   'minimum_orbit_intersection': '.0425474',
#                   'observations_used': 27,
#                   'orbit_class': {'orbit_class_description': 'Near-Earth '
#                                                              'asteroid orbits '
#                                                              'similar to that '
#                                                              'of 2062 Aten',
#                                   'orbit_class_range': 'a (semi-major axis) < '
#                                                        '1.0 AU; q (perihelion) '
#                                                        '> 0.983 AU',
#                                   'orbit_class_type': 'ATE'},
#                   'orbit_determination_date': '2026-01-12 05:54:57',
#                   'orbit_id': '2',
#                   'orbit_uncertainty': '6',
#                   'orbital_period': '337.8074756185119',
#                   'perihelion_argument': '143.0986734531935',
#                   'perihelion_distance': '.8134350651098854',
#                   'perihelion_time': '2461165.625858083476',
#                   'semi_major_axis': '.9492498843183539'}}

# %%
def closest_miss2(neos_data):
  date = ""
  miss_km = float('inf')
  neo_name = ""

  for neo in neos_data:
    for record in neo['close_approach_data']:
      if record["orbiting_body"] == "Earth" and start_date <= record["close_approach_date"] <= end_date and (float(record["miss_distance"]["kilometers"]) < float(miss_km)):
        miss_km = record["miss_distance"]["kilometers"]
        date = record["close_approach_date"]
        neo_name = neo["name"][1:-1]
  return (date, miss_km, neo_name)

date, miss_km, neo_id = closest_miss2(neos_data)

# information about the NEO, when it will approach the Earth, and how close it will come.
print(f"The closest NEO this week will be NEO {neo_id},\nand it will miss Earth by {miss_km} kilometers on {date}.")
# Out:
# The closest NEO this week will be NEO 2022 OB5,
# and it will miss Earth by 645385.691128403 kilometers on 2026-01-14.
